# %%
import pandas as pd

# %%
df=pd.read_csv("IRIS.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
list(df)
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %%
import seaborn as sns

# %%
sns.distplot(df['sepal_length'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12228\537145680.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sepal_length'])
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.distplot(df['sepal_width'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12228\3264937649.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sepal_width'])
# <AxesSubplot:xlabel='sepal_width', ylabel='Density'>

# %%
sns.distplot(df['petal_length'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12228\1576753295.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_length'])
# <AxesSubplot:xlabel='petal_length', ylabel='Density'>

# %%
sns.distplot(df['petal_width'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12228\3193493166.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_width'])
# <AxesSubplot:xlabel='petal_width', ylabel='Density'>

# %%
sns.boxplot(x='sepal_length',data = df)
# Out:
# <AxesSubplot:xlabel='sepal_length'>

# %%
sns.boxplot(x='sepal_width',data = df)
# Out:
# <AxesSubplot:xlabel='sepal_width'>

# %%
sns.boxplot(x='petal_length',data = df)
# Out:
# <AxesSubplot:xlabel='petal_length'>

# %%
sns.boxplot(x='sepal_width',data = df)
# Out:
# <AxesSubplot:xlabel='sepal_width'>

# %%
sns.boxplot(y='sepal_length',data = df)
# Out:
# <AxesSubplot:ylabel='sepal_length'>

# %%
df.describe(include = 'object')
# Out:
#             species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
print("\n\nThe features in the dataset are as follows : ")
print("1. Sepal length : ", df['sepal_length'].dtype)
print("2. Sepal width : ", df['sepal_width'].dtype)
print("3. Petal length : ", df['petal_length'].dtype)
print("4. Petal width : ", df['petal_width'].dtype)
print("5. Species : ", df['species'].dtype)
# Out:
# The features in the dataset are as follows :
# 1. Sepal length :  float64
# 2. Sepal width :  float64
# 3. Petal length :  float64
# 4. Petal width :  float64
# 5. Species :  object

# %%
sns.histplot(x = df['sepal_length'], kde=True)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(x = df['sepal_width'], kde=True)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(x = df['petal_length'], kde=True)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(x = df['petal_width'], kde=True)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Count'>

# %%
sns.boxplot(df['sepal_length'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['sepal_width'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['petal_length'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='sepal_length',y='species',data=df)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %%
sns.boxplot(x='petal_length',y='species',data=df)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='species'>
